# %%
import tkinter as tk
from bs4 import BeautifulSoup
import requests

import torch
from transformers import BertTokenizerFast, EncoderDecoderModel
from transformers import T5ForConditionalGeneration, AutoTokenizer
from transformers import pipeline
nlp = pipeline("question-answering", model="PlanTL-GOB-ES/roberta-large-bne-sqac")

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

ckpt_sum = 'mrm8488/bert2bert_shared-spanish-finetuned-summarization'
tokenizer_sum = BertTokenizerFast.from_pretrained(ckpt_sum)
model_sum = EncoderDecoderModel.from_pretrained(ckpt_sum).to(device)

def generate_summary(text):
  inputs = tokenizer_sum([text], padding="max_length", truncation=True, max_length=512, return_tensors="pt")
  input_ids = inputs.input_ids.to(device)
  attention_mask = inputs.attention_mask.to(device)
  output = model_sum.generate(input_ids, attention_mask=attention_mask)
  return tokenizer_sum.decode(output[0], skip_special_tokens=True)
# Out:
# The following encoder weights were not tied to the decoder ['bert/pooler']
# The following encoder weights were not tied to the decoder ['bert/pooler']
# The following encoder weights were not tied to the decoder ['bert/pooler']
# The following encoder weights were not tied to the decoder ['bert/pooler']

# %%
news = {}
messages = {}
sumaries = {}
current_conversation = [""]
message_entry = None
messsages_text = None

# %%
def get_answer(question, context):
  respObj = nlp(question, context)
  resp = ""
  if respObj['score'] < 0.4:
      resp += "La siguiente respuesta puede no ser correcta: "
      
  resp += respObj['answer']

  return resp


def add_conversation(conversation): # ,conversation_menu
    if conversation not in messages:
        messages[conversation] = []

    # conversation_menu["values"] = tuple(messages.keys())

def change_conversation(conversation=None):
    if conversation:
        current_conversation[0] = conversation
    load_messages()

def load_messages():
    # current_conversation = self.conversation_menu.get()

    messages_text.config(state="normal")
    messages_text.delete(1.0, tk.END)

    for sender, message in messages.get(current_conversation[0], []):
        messages_text.insert(tk.END, f"{sender}: {message}\n\n")

    messages_text.config(state="disabled")

def send_message(sender=None, message=None):
    # current_conversation = self.conversation_menu.get()
    if not sender:
        sender = "Usuario"
    if not message:
        if message_entry:
            message = message_entry.get()
        else:
            message = "Error no message entry"

    if message:
        messages[current_conversation[0]].append((sender, message))
        if message_entry:
            message_entry.delete(0, "end")
        load_messages()
        
def send_message_and_resp():
    message = message_entry.get()
    send_message()
    send_message("ChatBot",get_answer(context=news[current_conversation[0]], question=message))
 
class ScrolledCanvas():
    def __init__(self, parent, color='white'):
        canv = tk.Canvas(parent, bg=color, relief=tk.SUNKEN)
        canv.config(width=420, height=200)                
 
        ##---------- scrollregion has to be larger than canvas size
        ##           otherwise it just stays in the visible canvas
        canv.config(scrollregion=(0,0,300, 80*len(news)))         
        canv.config(highlightthickness=0)                 

        ctr=0
        for new in news:
            result = get_Titulo(new)
            frm = tk.Frame(parent, width=100, height=90, bg="#cfcfcf",bd=1)
            frm.config(relief=tk.SUNKEN)
            tk.Label(frm, text="Noticia #"+str(ctr+1)+":", font='Helvetica 9').grid(row=0, column=0, sticky="w")
            tk.Button(frm, text=result, command=lambda c=result: change_conversation(c), font='Helvetica 12 bold').grid(row=1, column=0)
            canv.create_window(10,10+(80*ctr),anchor=tk.NW, window=frm)
            ctr+=1
 
        ybar = tk.Scrollbar(parent)
        ybar.config(command=canv.yview)                   
        ## connect the two widgets together
        canv.config(yscrollcommand=ybar.set)              
        ybar.pack(side=tk.RIGHT, fill=tk.Y)                     
        canv.pack(side=tk.LEFT, expand=tk.YES, fill=tk.BOTH)
        
def get_Titulo(new):
    input_string = new
    result = input_string.split("_", 1)[0].strip()
    return result

def get_Noticia(new):
    input_string = new
    result = input_string.split("_", 1)[1]
    return result

def get_Noticias():
    url = "https://www.jornada.com.mx/rss/edicion.xml?v=1"

    page_to_scrape = requests.get(url)
    soup = BeautifulSoup(page_to_scrape.text.encode('latin-1').decode('utf-8'), "xml")

    newsItems = soup.findAll("item")

    print(newsItems[0])
    print(newsItems[1])
    
    res = {}

    for new in newsItems:
        # omitir opinion
        link = new.find("link").text
        if "opinion" in link:
            continue

        # construir noticia
        title = new.find("title")
        desc = new.find("description")
        txt = title.text + " _ " + desc.text
        res[get_Titulo(txt)]=txt
        
    return res

def set_conversations():
    for new in news:
        titulo = get_Titulo(news[new])
        print(titulo)
        add_conversation(titulo)
        current_conversation[0] = titulo
        change_conversation()
        send_message("ChatBot",titulo)
        send_message("ChatBot","Resumen: "+sumaries[titulo])
        send_message("ChatBot","Completa: "+get_Noticia(news[new]))
    
    first_key = list(news.keys())[0]
    current_conversation[0] = get_Titulo(news[first_key])
    change_conversation()
    
def set_sumaries():
    for new in news:
        sumaries[new] = generate_summary(new)

# %%
for new in news:
    print(new)
# Out:
# Se rebela dirigencia estatal panista; sigue en la coalición, advierte
# Critica Enrique Alfaro “absurdo y banalidad” en destape de Álvarez Máynez
# Víctor M. Quintana S.: La profecía actuante de las comunidades zapatistas
# Seco, al menos 70% del lago de Cuitzeo, alertan
# El frente frío 25 deja estragos en 13 municipios de Veracruz
# Washington, a favor de crear un Estado palestino, afirma Blinken ante Abbas
# Tribunal aprueba que Taddei realice los nombramientos claves en el INE
# Confrontación verbal en la Permanente por balance de quinto año
# Frustran EU y Reino Unido ataque de rebeldes hutíes en el mar Rojo
# Ejecutivo insiste a SCJN: extinción de fideicomisos es constitucional
# Hila dos años ingreso de capital extranjero a bonos del gobierno
# Multan a Brasil y Argentina por gresca en el Maracaná
# El hijo menor de Alain Delon demanda a su hermana por abuso en perjuicio de su padre
# El ejército vigila calles semivacías en Ecuador
# Gasolina y gas LP, botines codiciados por delincuentes en vías de comunicación
# Sergio Ramírez: Yo no olvido el año viejo
# Mario Patrón: 2024: dilemas centrales para una agenda pertinente
# Ministros Pérez Dayán y Aguilar Morales sí podrán decidir sobre amparos contra la ley eléctrica
# “Cerré mi empresa; no quise dejar huérfanos a mis hijos”
# Se disparan costos de los seguros para autos de carga
# AMLO celebra la postulación en el partido naranja
# El helicóptero Ingenuity aterrizó con éxito en Marte
# Sancionan a Overmars por acosar a empleadas del Ajax
# Tribunal boliviano ratifica remplazo de gobernador cruceño
# Presentará Xóchitl Gálvez una denuncia ante el INE
# Consejo Judicial propondrá terna para nombrar a titular de la FGJ
# Se disparan costos de los fletes marítimos
# Asesinan en su casa a la gobernadora de la etnia cucapá, Aronia Wilson; un detenido
# Sudcorea, principal enemigo: Kim Jong-un
# Atacan a opositor nicaragüense exiliado en Costa Rica
# Mujer con mantilla blanca en resguardo de El Prado
# Napoleón Gómez Urrutia: Fortaleciendo lazos de solidaridad
# La Federación ha invertido 25 mil 689 mdp en Acapulco y Coyuca
# Boeing investiga la falla; se quedan en tierra los 737 Max
# Investiga Cofece prácticas monopólicas en el transporte ferroviario de carga
# Ricardo Guzmán Wolffer: Outsorcing aprobado: corte efectiva
# Rechaza Sheinbaum señalamientos de la ex titular de Notimex
# Morena buscará consenso en el Senado para sacar reformas y nombramientos pendientes
# Proponen prohibir acarreo de indocumentados a actos de campaña
# Morena, PT y PAN llevarán trabajos de la permanente
# Desinformación y bulos, amenazas “moderadamente graves”, revela WEF
# Llega La Otra FIL a Rosamorada, Nayarit, una fiesta de libros sin politiquerías
# La UE pide a Swift invitar a jóvenes electores a registrarse
# Arranca el Ahumada Fest en Radio Educación
# Por heladas suben frutas y verduras; jitomate, en $70
# Solidaridad con el gobierno y pueblo ecuatorianos: AMLO
# Hoy, primera audiencia en la CIJ sobre acusación de genocidio contra Israel
# Delgado: no habrá candidaturas impuestas
# Mis abogados tienen las pruebas de las irregularidades, dice la ex funcionaria
# Junts per Catalunya logra concesiones al dejar pasar dos decretos del presidente de España
# Salario promedio de trabajadores formales acumula avance de 51.8% en lo que va del sexenio
# Convocan al tercer Encuentro Nacional de Ejecutivos de Orquesta
# Trabajadores denuncian abandono del hospital veterinario Iztapalapa
# Rarámuris ganan en la SCJN juicio a minera sobre uso del río Fuerte
# AMLO: Sanjuana Martínez debe demostrar sus dichos sobre funcionarios de STPS
# John Saxe-Fernández: Abismos de la ultraderecha
# Muere a los 85 años el  ex procurador general Sergio García Ramírez
# Financiera Nu entra al mercado de remesas
# Milei cumple un mes de gobierno entre fuerte rechazo en Argentina
# Bogotá militariza la frontera con Quito
# Vecinos, a disgusto con campamento otomí en la Juárez desde 2017
# Rompen alianza PAN y PRI en Coahuila tras ventilar pacto para repartirse instituciones
# Gobierno impulsa reformas para evitar delitos inmobiliarios
# Rememoran la lucha social de Víctor Rico Galán a 50 años de su fallecimiento
# Heat cae ante el Thunder
# Ssa: en 2023 hubo mil 912 fallecimientos por covid-19
# Compositoras mexicanas reivindican su lugar en un “gueto masculino”
# Desea López Obrador pronta recuperación  a José Agustín
# Real Madrid se impone en tiempo extra y es finalista de la Supercopa
# Salomón Jara “decepciona” a indígenas
# Masas de “químicos eternos” circulan por todo el mundo a través de océanos
# Inversión productiva se recupera y el consumo cae: Inegi
# Ningún país presta tantos y tan buenos servicios a sus connacionales en el exterior como México, dice Bárcena
# Avala el regulador de Estados Unidos los ETF asociados al bitcóin
# El simio más grande se habría extinguido por inadaptación a cambios en el clima
# Canales de Xochimilco, con agua contaminada y pestilente; impacta actividades turísticas
# Enredo en la Permanente: rinde homenaje luctuoso anticipado al jurista
# PRI expulsa a las 2 que apoyaron
# Abraham Nuncio: La lista incómoda
# Queremos que más mujeres compitan y trabajen en el automovilismo: Moutet
# Salinas Pliego acusa a vocero de la Presidencia de dirigir campaña contra Azteca
# TEPJF ordena reabrir queja contra Gálvez
# Un mosaico de creadoras impulsa una pléyade de dramaturgas
# Abraham Ancer mantiene esperanza de representar a México en París 2024
# Túnel secreto en sinagoga de NY provoca altercado
# Comenzó el desalojo de migrantes en albergues de Nueva York
# Víctimas de ciberacoso, 2.9 millones de jóvenes de 12 a 17 años en México
# Por anomalías, el INE frena la contratación de 214 capacitadores
# “Acabaremos con la vieja política”, dice Álvarez Máynez al registrarse por MC
# Morena buscará que fiscales se elijan por voto popular
# Caravana de migrantes pide a Oaxaca apoyarlos con transporte
# Garantizan que se hará el Tianguis Turístico  en el puerto
# No habrá tregua para construir la paz que Tamaulipas necesita: vocero de seguridad
# Luego de su fracaso en Qatar, Funes Mori espera que Pumas lo regrese al Tricolor
# Carreteras del país, auténticos infiernos por tiroteos y robos
# Reabrieron 51.5% de las escuelas en los dos municipios
# Jugar en el Azteca es mágico, pero ahora toca hacerlo en Coapa: Villacampa
# Residentes de la colonia Guadalupe Inn se oponen a cambio de uso de suelo
# Matan a chofer para robar calentadores solares
# Tras la huelga de 118 días, el SAG revela a sus favoritos: Barbie y Oppenheimer
# Unesco sugiere medidas contra desinformación y violencia extrema en redes
# Magú
# El Fisgón
# Rocha

# %%
set_sumaries()

# %%
sumaries
# Out:
# {'Se rebela dirigencia estatal panista; sigue en la coalición, advierte': 'Se indigna dirigencia estatal panista ; sigue en la coalición, adviertencia estatal',
#  'Critica Enrique Alfaro “absurdo y banalidad” en destape de Álvarez Máynez': 'El absurdo y banalidad en destape de Álvarez Máynez se destape del Áilómetro Máynz, el presidente de la Comisión de Competencia de Madrid, que ha sido destape, ha destapado de Ángel Máyndez de Álava, en la que se analizaba de de',
#  'Víctor M. Quintana S.: La profecía actuante de las comunidades zapatistas': 'La profecía actuante de las comunidades zapatistas de zapatistas zapatistas en el país sudamericano es una de las razones por las cuales la profecía se ha hecho viral',
#  'Seco, al menos 70% del lago de Cuitzeo, alertan': 'Seco, al menos 70 % del lago de Cuitzeo, alertan los expertos sobre el lago de Potzeo',
#  'El frente frío 25 deja estragos en 13 municipios de Veracruz': 'El frente frío 25 deja estragos en 13 municipios de Veracruz de Veracruz',
#  'Washington, a favor de crear un Estado palestino, afirma Blinken ante Abbas': 'Washington, a favor de crear un Estado palestino, dice Blinken ante Abbasken',
#  'Tribunal aprueba que Taddei realice los nombramientos claves en el INE': 'El Tribunal aprueba que Taddei realizar los nombramientos clave en el INE para el INE de la elección del INE que sedd en el cálculo del INE, según Taddi Tadd de la consulta del INE',
#  'Confrontación verbal en la Permanente por balance de quinto año': 'La Permanente por balance de quinto año consecutivo, quinto año año nuevo año, ha sido superado por un año año año después de cinco años, el año ha pasado con un quinto año de cinco año año en la Permanente',
#  'Frustran EU y Reino Unido ataque de rebeldes hutíes en el mar Rojo': 'El mar Rojo de la UE y Reino Unido ataque de rebeldes hutíes en el mar Rojo. Frustran EU y Reino británico ataque de las fuerzas europeas y Reino Reino Unido atacan a las fuerzas del mar Rojo del mar rojo rojo rojo y rojo rojo Rojo. El mar rojo Rojo de las europeas y de',
#  'Ejecutivo insiste a SCJN: extinción de fideicomisos es constitucional': 'Viñeta de El Roto del 6 de diciembre de 2017',
#  'Hila dos años ingreso de capital extranjero a bonos del gobierno': 'Hila dos años ingreso de capital extranjero a bonos del gobierno gobierno de los gobiernos del gobierno del gobierno de Hila Dos años',
#  'Multan a Brasil y Argentina por gresca en el Maracaná': 'Multan a Brasil y Argentina por gresca en el Maracaná en el maracaná de Argentina',
#  'El hijo menor de Alain Delon demanda a su hermana por abuso en perjuicio de su padre': 'El hijo menor de Alain Delon demanda a su hermana por abuso en perjuicio de su padre',
#  'El ejército vigila calles semivacías en Ecuador': 'El Ejército de Ecuador controla calles semivacías en Ecuador, Ecuador y Ecuador. El Ejército controla las calles de las ciudades de Ecuador',
#  'Gasolina y gas LP, botines codiciados por delincuentes en vías de comunicación': 'Los botines codiciados por delincuentes en vías de comunicación comunicación de tráfico de gas Gas Gas de Gas Gas Gas gas gas y gas Gas gas y Gas Gasfa y gas gas gas en gas gas Gastel y gas de Gas gas de gas, un botines de gas gas, botín de gas de',
#  'Sergio Ramírez: Yo no olvido el año viejo': 'Sergio Ramírez : " No olvido el año viejo viejo viejo año viejo. Ya no recuerdo el año vieja viejo viejo "',
#  'Mario Patrón: 2024: dilemas centrales para una agenda pertinente': 'El dilemas centrales para la agenda de Mario Patrón sobre el tema central de los temas centrales para el tema tema central del tema central central de la agenda central para el debate central central sobre los problemas centrales para los próximos próximos próximos temas centrales sobre los desafíos centrales de los conflictos centrales',
#  'Ministros Pérez Dayán y Aguilar Morales sí podrán decidir sobre amparos contra la ley eléctrica': 'Los ministros Pérez Dayán y Aguilar Morales sí podrán decidir sobre amparos contra la ley eléctrica',
#  '“Cerré mi empresa; no quise dejar huérfanos a mis hijos”': 'Cerré mi empresa ; no quise dejar huérfanos a mis hijos mis hijos, afirma el exmandatario de la empresa',
#  'Se disparan costos de los seguros para autos de carga': 'Se disparan costos de los seguros para autos de carga cargando costos de seguros',
#  'AMLO celebra la postulación en el partido naranja': 'AMLO celebra la postulación en partido del partido naranja de AMLO, en partido de la campaña del partido de Podemos, que se ha postudo en el partido naranja del partido rojo de la derecha de AM, en de AM de AM',
#  'El helicóptero Ingenuity aterrizó con éxito en Marte': 'El aparato, que aterrizó con éxito en Marte en Marte, aterrizó en Marte con éxito con éxito',
#  'Sancionan a Overmars por acosar a empleadas del Ajax': 'El presidente del Ajax ha sido sancionado a Overn a Overman a Overmar a Overr a Over despido por Sancionan al Ajax de la Liga que ha acosado a las mujeres que han acos acosn a las empleadas de las mujeres de la Federación que han abus árbitron a la que',
#  'Tribunal boliviano ratifica remplazo de gobernador cruceño': 'El Tribunal boliviano ratifica remplazo de gobernador cruceño',
#  'Presentará Xóchitl Gálvez una denuncia ante el INE': 'Xóchitl Gálvez Gálveza presentará una denuncia ante del INE que presentó en la denuncia ante ante de la denuncia contra del INE del INE, que presentó la denuncia en el INE que presentará el recurso ante ante ante que presentó el recurso recurso ante en declarar ante ante al INE, Xó',
#  'Consejo Judicial propondrá terna para nombrar a titular de la FGJ': 'El Consejo Judicial propondrá terna para nombrar a titular de la FGJ',
#  'Se disparan costos de los fletes marítimos': 'Se disparan costos de los fletes marítimos marítimos, pero se disparan los costos de fletes',
#  'Asesinan en su casa a la gobernadora de la etnia cucapá, Aronia Wilson; un detenido': 'La gobernadora de la etnia cucapá, Aronia Wilson, ha sido Asesinan en su casa a la gobernadora del etnia Cucapá. Un detenido detenido por asesinato asesinato, un detenido detenido a muerte. Asesinaton en la casa de una mujer en la que se enfrentan a la',
#  'Sudcorea, principal enemigo: Kim Jong-un': 'El principal enemigo de Kim Jong - un - un es el principal enemigo del principal enemigo : Kim, principal enemigo, que se enfrenta a la principal enemigo',
#  'Atacan a opositor nicaragüense exiliado en Costa Rica': 'El oposoma de Costa Ata Atacan contra Atacan a Atavan contra Atavan a Ata Atazan contra Ata Atan contra Ata Amena Amena Amenaan contra Ata lin lin linzan a Atacan, que Ata Atavan Atacan defensa contra Atacar contra Ataca contra Ataan Ata Ataan a Ata',
#  'Mujer con mantilla blanca en resguardo de El Prado': 'La mujer con mantilla blanca en resguardo de El Prado Prado, Mujer con mansa blanca en blindo de La Prado Mujer Mujer Mujer en resguarda blanca con manta blanca en defensa Mujer Mujer de mujer con Man Mujer Mujer con Man femenina con mancilla blanca en mujer con con man man femenina mujer con',
#  'Napoleón Gómez Urrutia: Fortaleciendo lazos de solidaridad': '" Fortaleciendo lazos de solidaridad solidaridad solidaridad con la solidaridad solidaridad, la solidaridad y la solidaridad de las personas, así como el respeto a la solidaridad internacional "',
#  'La Federación ha invertido 25 mil 689 mdp en Acapulco y Coyuca': 'La Federación ha invertido 25 mil 689 md en Acapulco y Coyuca',
#  'Boeing investiga la falla; se quedan en tierra los 737 Max': 'Boeing investiga la falla ; se quedan en tierra los 73 Max Max de Boeing',
#  'Investiga Cofece prácticas monopólicas en el transporte ferroviario de carga': 'La investigación de Cofece práctica práctica de investigación monopólica en el transporte de un tren de carga de carga carga de cargas monopólicas en la que investiga Cofecta práctica práctica práctica en la investigación de cómo se investiga Co de investigaciones mono de investigación de investiga Co pune prácticas prácticas prácticas de investiga práctica',
#  'Ricardo Guzmán Wolffer: Outsorcing aprobado: corte efectiva': 'Ricardo Guzmán Wolffer : corte efectiva, corte efectiva y corta efectiva. Ricardo Guzmán, guionista de Outsorcing. El guionista de la serie de Ricardo Guzmán',
#  'Rechaza Sheinbaum señalamientos de la ex titular de Notimex': 'La ex titular de Notimexxe Sheerza Sheinbaum señalamientos de la ex titular del Notimezxxxz Shezza Sheiza Shenza Shebaum de la antigua titular de notificaciónmexex de una ex de ella que señalamientosmientos de',
#  'Morena buscará consenso en el Senado para sacar reformas y nombramientos pendientes': 'Morena buscará consenso en el Senado para sacar reformas pendientes pendientes pendientes de Morena',
#  'Proponen prohibir acarreo de indocumentados a actos de campaña': 'Proponen prohibir acarreo de indocumbe indocumentados a actos de campaña campaña de la campaña de Pro proponen prohibir la prohibición prohibición de acarreo indocumentado a actos campaña campaña campaña electoral en pro de la prohibición de los indocumfrica',
#  'Morena, PT y PAN llevarán trabajos de la permanente': 'Morena, PT, PT y PAN llevarán trabajos de la permanente permanente y la permanente',
#  'Desinformación y bulos, amenazas “moderadamente graves”, revela WEF': 'Desinformación y bulos, amenazas moderadamente graves, amenazas de moderador graves',
#  'Llega La Otra FIL a Rosamorada, Nayarit, una fiesta de libros sin politiquerías': 'La Otra FIL a Rosamorada, Nayarit, una fiesta de libros sin politiqueríasrías, una celebración de libros con politiqueríarías y un espectáculo de lectura en la celebración de la lectura de libros. Llega La Otro FIL en una fiesta en la que llega La Otra',
#  'La UE pide a Swift invitar a jóvenes electores a registrarse': 'La UE pide a Swift invitar a jóvenes electores a inscribirsese en la UE petición de la UE UE, que pide a los jóvenes que se inscribirse en el registro de una UE que exige a jóvenes de un país común que no puede registrarse en un registro de de la Unión UE que',
#  'Arranca el Ahumada Fest en Radio Educación': 'Arranca el Ahumada Fest en Radio Educación Educación en Radio educación Educación Educación',
#  'Por heladas suben frutas y verduras; jitomate, en $70': 'El periodista de EL PAÍS Rubén Amón analiza las claves de la campaña electoral del 22 - M',
#  'Solidaridad con el gobierno y pueblo ecuatorianos: AMLO': 'Sigue en EL PAÍS VÍDEO las declaraciones del presidente y pueblo ecuatoriano sobre el Gobierno y pueblo',
#  'Hoy, primera audiencia en la CIJ sobre acusación de genocidio contra Israel': 'La primera audiencia en la CIJ sobre acusación de genocidio contra Israel contra Israel Israel Israel, primera sesión en la que la cita en la CiJ sobre el tema de acusación de terrorismo contra Israel',
#  'Delgado: no habrá candidaturas impuestas': 'Delgado : no habrá candidaturas impuestas impuestas impuestas, impuestas delgado, no habrá candidatura impuestas impuestas de estegado, delgado : se Delgado',
#  'Mis abogados tienen las pruebas de las irregularidades, dice la ex funcionaria': 'Mis abogados tienen las pruebas de las irregularidades, dice la ex funcionaria',
#  'Junts per Catalunya logra concesiones al dejar pasar dos decretos del presidente de España': 'Junts per Catalunya consigue concesiones al dejar pasar dos decretos del presidente de España España España',
#  'Salario promedio de trabajadores formales acumula avance de 51.8% en lo que va del sexenio': 'La Salario promedio de trabajadores formales acumula avance de 51. 8 % en lo que va del sexenio de los trabajadores formalmente acumula avance aumento de 53. 87 trabajadores formal acumula avances de 51, 8 %. El año que acaba de llegar en el cuarto mes de la semana del año, el',
#  'Convocan al tercer Encuentro Nacional de Ejecutivos de Orquesta': 'El tercer encuentro del tercer encuentro de Gobierno de Orquestan al tercer encuentro encuentro, se convierte en el tercer encuentro con el tercer Encuentro',
#  'Trabajadores denuncian abandono del hospital veterinario Iztapalapa': 'Trabajadores denuncian el abandono del hospital de Iztapalpalapaapaapapó del hospital a los trabajadores denunciann abandono del centro sanitario',
#  'Rarámuris ganan en la SCJN juicio a minera sobre uso del río Fuerte': 'Rarámuris ganan en la SCJN juicio a minera sobre uso del río del río de Fuerte disputa sobre el río de un río en la SEJN que gana en la SGJN',
#  'AMLO: Sanjuana Martínez debe demostrar sus dichos sobre funcionarios de STPS': 'Sanjuana Martínez deberá demostrar sus dichos dichos dichos sobre funcionarios de la STPS',
#  'John Saxe-Fernández: Abismos de la ultraderecha': 'La ultraderecha de izquierda extrema derecha se ha convertido en la primera línea de la izquierda política española en la que el Gobierno de Rajoy se pronuncia a la derecha derecha extrema extrema derecha',
#  'Muere a los 85 años el  ex procurador general Sergio García Ramírez': 'El ex procurador general Sergio García Ramírez muere a los 85 años',
#  'Financiera Nu entra al mercado de remesas': 'Vi al mercado de remesas financieras, entra al sector de remesa entrada financiera entra al mercado del mercado de las remesas. Esta entra al valor de la entrada al mercado. Entra al mercado en el mercado de la empresa del mercado financiero entra al grupo al mercado este entra al mercados financiero entra entra al este',
#  'Milei cumple un mes de gobierno entre fuerte rechazo en Argentina': 'Milei cumple un mes de gobierno entre fuerte rechazo rechazo en Argentina Argentina, pero cumple una semana de gobierno en Argentina. Milei celebra el primer mes de Gobierno en Argentina, desde un mes del Gobierno de Milei cumplido en Argentina',
#  'Bogotá militariza la frontera con Quito': 'La ciudad militar militariza la frontera con Quito, con Quito de Bogotá, se militar de la frontera de la capital de Bogotá Bogotá, Bogotá militar la frontera centroiza la zona de la ciudad de Bogotá ciudad centro de la centro centro de Colombia Bogotá Bogotá Bogotá de Bogotá este centro centro centro la centro de centro de Bogotá',
#  'Vecinos, a disgusto con campamento otomí en la Juárez desde 2017': 'Vecinos, a disgusto con campamentos otomí en la Juárez desde 2017, han sido desalojados de la Jordania desde 201ba, desde 2007 años, en 20177 años después de 2017 años otomí desde 201amaica, desde 201 musulmana, desde los últimos años años,',
#  'Rompen alianza PAN y PRI en Coahuila tras ventilar pacto para repartirse instituciones': 'Rompen alianza PAN y PRI en Coahuila tras ventilar pacto para repartirse instituciones instituciones diferentes',
#  'Gobierno impulsa reformas para evitar delitos inmobiliarios': 'El Gobierno impulsa una reforma para evitar delitos inmobiliarios',
#  'Rememoran la lucha social de Víctor Rico Galán a 50 años de su fallecimiento': 'Repemoran la lucha social de Víctor Rico Galán a 50 años de su muerte fallecimiento',
#  'Heat cae ante el Thunder': 'Heat cae ante el Thunder del Thunder, pero heat cae frente al Thunder de Heat',
#  'Ssa: en 2023 hubo mil 912 fallecimientos por covid-19': 'Ssa : en 2023 hubo 912 fallecimientos fallecimientos por covid - 19 - 19. 000 fallecimientos en la última jornada de la jornada en la que hubo mil mil mil 912 muertess por Covid - 49 - 192 - 19',
#  'Compositoras mexicanas reivindican su lugar en un “gueto masculino”': 'Las mujeres reivindican su lugar en un gueto masculino masculino en un gueto femenino',
#  'Desea López Obrador pronta recuperación  a José Agustín': 'José Agustín de deseo López Obrador, se Desea López Desea López Obrado, que ha Deseado López Obratero, ha deseodo López deseo López opción opción opciones opción opciones opciones opciones deseo López deseoxi López deseoo López Obra López Obrao desear López opción López desear López Obra opción opción opción López opción opciones',
#  'Real Madrid se impone en tiempo extra y es finalista de la Supercopa': 'El Real Madrid se impone en tiempo extra y es finalista de la Supercopa española, finalista y finalista del partido extra de esta Supercopa',
#  'Salomón Jara “decepciona” a indígenas': 'Salomón Jara decepciona a indígenas indígenas indígenas de Salomón, que ha logrado hablar con Salomón kara, que se encuentra con la indígenas Salomón de Salomón Salomón, Salomón de la India Salomón Salomón de género Jara, que Salomón de los indígenas indígenas Salomón Salomón J kara, Salomón Ji Salomón',
#  'Masas de “químicos eternos” circulan por todo el mundo a través de océanos': 'Masas de químicos eternos circulan por todo el mundo a través de océanos océanos eternos',
#  'Inversión productiva se recupera y el consumo cae: Inegi': 'La inversión productiva se recupera y el consumo cae : Inegi y el empleo retroceden',
#  'Ningún país presta tantos y tan buenos servicios a sus connacionales en el exterior como México, dice Bárcena': 'El país presta tantos y tan buenos servicios a sus connacionales en el exterior como México, dice Bárcenas',
#  'Avala el regulador de Estados Unidos los ETF asociados al bitcóin': 'Avala el regulador de Estados Unidos los atentados terroristas del bitcóinin Ass Avan el regulador del regulador de EE UU los ETdeosin de EE Estados Unidos',
#  'El simio más grande se habría extinguido por inadaptación a cambios en el clima': 'El simio más grande se habría extinguido por inadaptación a cambio de cambios en el clima clima climático',
#  'Canales de Xochimilco, con agua contaminada y pestilente; impacta actividades turísticas': 'El Canal de Xochimilco, con agua contaminada y pestilente ; impacta actividades turísticas y turísticas',
#  'Enredo en la Permanente: rinde homenaje luctuoso anticipado al jurista': 'Enredo, enredo en la Permanente : rinde homenaje luctuoso anticipado anticipado al jurista fallecido',
#  'PRI expulsa a las 2 que apoyaron': 'PRI expulsa a las 2 que apoyar apoyaron apoyarononon a las que apoyaron apoyóonon apoyar apoyar apoyar de las dos que apoyar votar apoyaron apoyo de la defensa del partido de la oposición, expulsar de Podemos Podemos, expulsara de las que respal apoyar apoyar respaldo de las mujeres',
#  'Abraham Nuncio: La lista incómoda': 'La lista incómoda para el candidato de Abraham Nuncio es la de Gabriel Nundo. La lista más incómoda de la lista de candidatos presidenciales es la primera incómoda línea incómoda. El tema de La lista de incómoda es el tema que se plantea Abraham Nujardo',
#  'Queremos que más mujeres compitan y trabajen en el automovilismo: Moutet': 'Queremos que más mujeres compitan y trabajen en el automovilismo : Moutettt, que más femenino competiran y trabajaran en el vehículo urbano : mofatt y trabajar en el motor urbano',
#  'Salinas Pliego acusa a vocero de la Presidencia de dirigir campaña contra Azteca': 'Salinas Pliego acusa a vocero de la presidencia contra Azanas Pliego acusado contra contra de Azteca acusa contra acusaciones acusaciones de antiate acusa contra contranasnas Plo acusa contra rostro acusaciones contra contra del presidente de Podemos contra contra contra nombre contra contra presidente de contra contra que acusa acusa contra de de de',
#  'TEPJF ordena reabrir queja contra Gálvez': 'El Tribunal Supremo del Tribunal Supremo de la República Democrática del Tribunal de Derechos de Derechos Humanos, que puede ser sancionado de este miércoles a la semana que ha sido citado a este miércoles que ha podido que que que puede decidir que que debe ser que puede que ser que que deberá que ser ser que mismo que que',
#  'Un mosaico de creadoras impulsa una pléyade de dramaturgas': 'Un mosaico de creadoras impulsa una pléyade de dramatur dramatur dramaturgas y dramatur dramaturjantes',
#  'Abraham Ancer mantiene esperanza de representar a México en París 2024': 'El presidente de Abraham Ancer mantiene esperanza de representar a México en el país mexicano en esperanza de México, que ha esperanza de este país mexicano de esperanza de la esperanza de Abrahamsti Abraham Abraham en esperanza para el año de Abraham Abraham Abraham',
#  'Túnel secreto en sinagoga de NY provoca altercado': 'El ataque de NY provoca altercados entre altercados por altercados en sinagoga en NY. Un altercado altercado con altercados de altercados choques de choque en el centro de la NY',
#  'Comenzó el desalojo de migrantes en albergues de Nueva York': 'El desalojo de migrantes en albergues de Nueva York ha sido desalojado de sus albergues',
#  'Víctimas de ciberacoso, 2.9 millones de jóvenes de 12 a 17 años en México': 'Las víctimas de ciberacoso, 2. 9 millones de jóvenes de 12 a 17 años en México en México, se enfrentan a la falta de acceso a Internet y a las redes de comunicación en el país mexicano',
#  'Por anomalías, el INE frena la contratación de 214 capacitadores': 'El INE frena la contratación de 214 capacitadores, 214 capacitados por el INE frenando la contratación del 214 capacitado',
#  '“Acabaremos con la vieja política”, dice Álvarez Máynez al registrarse por MC': 'El periodista Álvarez Máynez relata la historia de la vieja política y la política en su país',
#  'Morena buscará que fiscales se elijan por voto popular': 'Morena buscará que fiscales se elijan por voto popular popular',
#  'Caravana de migrantes pide a Oaxaca apoyarlos con transporte': 'El Caravana de migrantes pide a Oaxaca ayudar a Oaxaca ayuda a Oaxaca apoyar a la caravana de migrantes reclamados por transporte transporte de migrantes',
#  'Garantizan que se hará el Tianguis Turístico  en el puerto': 'Garantizan que se hará el Tianguis Turístico en el puerto puerto de la ciudad portuaria',
#  'No habrá tregua para construir la paz que Tamaulipas necesita: vocero de seguridad': 'No habrá tregua para construir la paz que Tamaulipas necesita : vocero de seguridad seguridad',
#  'Luego de su fracaso en Qatar, Funes Mori espera que Pumas lo regrese al Tricolor': 'Funes Mori espera que Pumas lo regrese al Tricolor Tricolores',
#  'Carreteras del país, auténticos infiernos por tiroteos y robos': 'Vis del país, presuntos infiernos, auténticos infiernos. Via ruta ruta ruta del país país, auténtico país, los últimos infiernos de este país, auténticos paraíso de la carretera carretera carretera carreteras carreteras carreteras, carreteras carreteras del país países países, auténticos carreteras carreteras carretera carretera ruta ruta carreteras carreteras ruta ruta carretera carretera',
#  'Reabrieron 51.5% de las escuelas en los dos municipios': 'Las escuelas en los dos municipios municipios de los dos pueblos de los municipios de la provincia de San Salvador fueron evacuadas por 51. 5 %',
#  'Jugar en el Azteca es mágico, pero ahora toca hacerlo en Coapa: Villacampa': 'Jugar en el Azteca es mágico, pero ahora toca hacerlo en Coapa : Villacampa es mágico',
#  'Residentes de la colonia Guadalupe Inn se oponen a cambio de uso de suelo': 'Residentes de la colonia Guadalupe Inn se oponen a cambio de uso de suelo de suelo suelo',
#  'Matan a chofer para robar calentadores solares': 'Las víctimas de Matan a chofer para robar calentadores solares para robar calefacción para robar caliente para robar calentar calentadores fotoñan a chofer calentadores deadores solares',
#  'Tras la huelga de 118 días, el SAG revela a sus favoritos: Barbie y Oppenheimer': 'El SAG revela a sus favoritos : Barbie y Oppenheimerheimer',
#  'Unesco sugiere medidas contra desinformación y violencia extrema en redes': 'Unesco sugiere medidas contra contra desinformación y violencia extrema en redes de unesco. Unesco propone medidas contra desin transformación y violencia contra desinicación y violencia para desinformación',
#  'Magú': 'Magúúúlogú de Magú Magúlogo que ha protagonizado el Magú del Magú mago Magú, que ha sido reconocido por Magú magia Magúgi Magúfa Magú virúú Magí Mag Magú Vi Magúv Magúg Magútal',
#  'El Fisgón': 'El Fisgón fisgón, el Fisgón del Fisgón, un Fisgón de fisgón en el fisgón del fisgón',
#  'Rocha': 'Rochaha de Roc Rocha Roc Roc Rocera Roc Roc rocera, Rocha Unidos Roc Rocieha Roc roc rocera contra rochaha, roc punhahaha roc pun pun punha y Roc Roc pun roc roc roc Roc pun punuenuenca roc roc pun roc Roc roc pun Roc'}

# %%
window = tk.Tk()
window.title("Simple Text Editor")

window.rowconfigure(0, minsize=300, weight=1)
window.columnconfigure(1, minsize=300, weight=1)

frm_buttons = tk.Frame(window, relief=tk.RAISED, bd=2)
frm_buttons.grid(row=0, column=0, sticky="ns")

chat_frame = tk.Frame(window, bd=2)
chat_frame.grid(row=0, column=1, sticky="nsew")

# Inicializar el área de conversación
messages_text = tk.Text(chat_frame, wrap="word", state="disabled", font="Helvetica 12")
messages_text.grid(row=0, column=0, padx=5, pady=5, sticky="nsew")
scrollbar = tk.Scrollbar(chat_frame, command=messages_text.yview)
scrollbar.grid(row=0, column=1, sticky="ns")
messages_text["yscrollcommand"] = scrollbar.set

# Inicializar el campo de entrada de mensajes
message_entry = tk.Entry(chat_frame, width=50, font="Helvetica 12")
message_entry.grid(row=1, column=0, padx=5, pady=5, sticky="w")
tk.Button(chat_frame, text="Enviar Mensaje", command=send_message_and_resp).grid(row=1, column=1, pady=5)

news = get_Noticias()
messages = {}
set_conversations()

print(messages)

ScrolledCanvas(frm_buttons)
window.mainloop()
# Out:
# <item>
# <title>Editorial: Trump: mendacidad letal </title>
# <link>https://www.jornada.com.mx/2024/01/11/opinion/002a1edi?partner=rss</link>
# <description>El ex presidente  Donald Trump volvió a usar a los migrantes indocumentados como eje de su campaña para regresar a la Casa Blanca. Días atrás, recurrió a una terminología claramente eugenésica y filonazi para exigir el cierre de la frontera con México bajo el argumento de que las personas procedentes de América Latina, el Caribe, África o Medio Oriente “ensucian” la sangre de los estadunidenses. Ahora, cuando están a punto de comenzar las primarias (elecciones internas) del Partido Republicano para seleccionar a su candidato, el magnate insiste en que la administración federal alienta a los migrantes para que entren en masa a Estados Unidos de manera irregular para registrarlos y que voten en la elección de 2024.</description>
# <pubDate>Thu, 11 Jan 2024 10:06:32 GMT</pubDate>
# </item>
# <item>
# <title>Se rebela dirigencia estatal panista; sigue en la coalición, advierte   </title>
# <link>https://www.jornada.com.mx/2024/01/11/politica/005n2pol?partner=rss</link>
# <description>Saltillo, Coah., La decisión del dirigente nacional del PAN, Marko Cortés, de romper la alianza electoral con el PRI, con miras a la próxima renovación de ayuntamientos en Coahuila, “merma el proyecto nacional” que en conjunto postula a Xóchitl Gálvez como candidata presidencial, advirtió el gobernador priísta Manolo Jiménez Salinas.</description>
# <pubDate>Thu, 11 Jan 2024 10:06:32 GMT</pubDate>
# </item>
# Se rebela dirigencia estatal panista; sigue en la coalición, advierte
# Critica Enrique Alfaro “absurdo y banalidad” en destape de Álvarez Máynez
# Víctor M. Quintana S.: La profecía actuante de las comunidades zapatistas
# Seco, al menos 70% del lago de Cuitzeo, alertan
# El frente frío 25 deja estragos en 13 municipios de Veracruz
# Washington, a favor de crear un Estado palestino, afirma Blinken ante Abbas
# Tribunal aprueba que Taddei realice los nombramientos claves en el INE
# Confrontación verbal en la Permanente por balance de quinto año
# Frustran EU y Reino Unido ataque de rebeldes hutíes en el mar Rojo
# Ejecutivo insiste a SCJN: extinción de fideicomisos es constitucional
# Hila dos años ingreso de capital extranjero a bonos del gobierno
# Multan a Brasil y Argentina por gresca en el Maracaná
# El hijo menor de Alain Delon demanda a su hermana por abuso en perjuicio de su padre
# El ejército vigila calles semivacías en Ecuador
# Gasolina y gas LP, botines codiciados por delincuentes en vías de comunicación
# Sergio Ramírez: Yo no olvido el año viejo
# Mario Patrón: 2024: dilemas centrales para una agenda pertinente
# Ministros Pérez Dayán y Aguilar Morales sí podrán decidir sobre amparos contra la ley eléctrica
# “Cerré mi empresa; no quise dejar huérfanos a mis hijos”
# Se disparan costos de los seguros para autos de carga
# AMLO celebra la postulación en el partido naranja
# El helicóptero Ingenuity aterrizó con éxito en Marte
# Sancionan a Overmars por acosar a empleadas del Ajax
# Tribunal boliviano ratifica remplazo de gobernador cruceño
# Presentará Xóchitl Gálvez una denuncia ante el INE
# Consejo Judicial propondrá terna para nombrar a titular de la FGJ
# Se disparan costos de los fletes marítimos
# Asesinan en su casa a la gobernadora de la etnia cucapá, Aronia Wilson; un detenido
# Sudcorea, principal enemigo: Kim Jong-un
# Atacan a opositor nicaragüense exiliado en Costa Rica
# Mujer con mantilla blanca en resguardo de El Prado
# Napoleón Gómez Urrutia: Fortaleciendo lazos de solidaridad
# La Federación ha invertido 25 mil 689 mdp en Acapulco y Coyuca
# Boeing investiga la falla; se quedan en tierra los 737 Max
# Investiga Cofece prácticas monopólicas en el transporte ferroviario de carga
# Ricardo Guzmán Wolffer: Outsorcing aprobado: corte efectiva
# Rechaza Sheinbaum señalamientos de la ex titular de Notimex
# Morena buscará consenso en el Senado para sacar reformas y nombramientos pendientes
# Proponen prohibir acarreo de indocumentados a actos de campaña
# Morena, PT y PAN llevarán trabajos de la permanente
# Desinformación y bulos, amenazas “moderadamente graves”, revela WEF
# Llega La Otra FIL a Rosamorada, Nayarit, una fiesta de libros sin politiquerías
# La UE pide a Swift invitar a jóvenes electores a registrarse
# Arranca el Ahumada Fest en Radio Educación
# Por heladas suben frutas y verduras; jitomate, en $70
# Solidaridad con el gobierno y pueblo ecuatorianos: AMLO
# Hoy, primera audiencia en la CIJ sobre acusación de genocidio contra Israel
# Delgado: no habrá candidaturas impuestas
# Mis abogados tienen las pruebas de las irregularidades, dice la ex funcionaria
# Junts per Catalunya logra concesiones al dejar pasar dos decretos del presidente de España
# Salario promedio de trabajadores formales acumula avance de 51.8% en lo que va del sexenio
# Convocan al tercer Encuentro Nacional de Ejecutivos de Orquesta
# Trabajadores denuncian abandono del hospital veterinario Iztapalapa
# Rarámuris ganan en la SCJN juicio a minera sobre uso del río Fuerte
# AMLO: Sanjuana Martínez debe demostrar sus dichos sobre funcionarios de STPS
# John Saxe-Fernández: Abismos de la ultraderecha
# Muere a los 85 años el  ex procurador general Sergio García Ramírez
# Financiera Nu entra al mercado de remesas
# Milei cumple un mes de gobierno entre fuerte rechazo en Argentina
# Bogotá militariza la frontera con Quito
# Vecinos, a disgusto con campamento otomí en la Juárez desde 2017
# Rompen alianza PAN y PRI en Coahuila tras ventilar pacto para repartirse instituciones
# Gobierno impulsa reformas para evitar delitos inmobiliarios
# Rememoran la lucha social de Víctor Rico Galán a 50 años de su fallecimiento
# Heat cae ante el Thunder
# Ssa: en 2023 hubo mil 912 fallecimientos por covid-19
# Compositoras mexicanas reivindican su lugar en un “gueto masculino”
# Desea López Obrador pronta recuperación  a José Agustín
# Real Madrid se impone en tiempo extra y es finalista de la Supercopa
# Salomón Jara “decepciona” a indígenas
# Masas de “químicos eternos” circulan por todo el mundo a través de océanos
# Inversión productiva se recupera y el consumo cae: Inegi
# Ningún país presta tantos y tan buenos servicios a sus connacionales en el exterior como México, dice Bárcena
# Avala el regulador de Estados Unidos los ETF asociados al bitcóin
# El simio más grande se habría extinguido por inadaptación a cambios en el clima
# Canales de Xochimilco, con agua contaminada y pestilente; impacta actividades turísticas
# Enredo en la Permanente: rinde homenaje luctuoso anticipado al jurista
# PRI expulsa a las 2 que apoyaron
# Abraham Nuncio: La lista incómoda
# Queremos que más mujeres compitan y trabajen en el automovilismo: Moutet
# Salinas Pliego acusa a vocero de la Presidencia de dirigir campaña contra Azteca
# TEPJF ordena reabrir queja contra Gálvez
# Un mosaico de creadoras impulsa una pléyade de dramaturgas
# Abraham Ancer mantiene esperanza de representar a México en París 2024
# Túnel secreto en sinagoga de NY provoca altercado
# Comenzó el desalojo de migrantes en albergues de Nueva York
# Víctimas de ciberacoso, 2.9 millones de jóvenes de 12 a 17 años en México
# Por anomalías, el INE frena la contratación de 214 capacitadores
# “Acabaremos con la vieja política”, dice Álvarez Máynez al registrarse por MC
# Morena buscará que fiscales se elijan por voto popular
# Caravana de migrantes pide a Oaxaca apoyarlos con transporte
# Garantizan que se hará el Tianguis Turístico  en el puerto
# No habrá tregua para construir la paz que Tamaulipas necesita: vocero de seguridad
# Luego de su fracaso en Qatar, Funes Mori espera que Pumas lo regrese al Tricolor
# Carreteras del país, auténticos infiernos por tiroteos y robos
# Reabrieron 51.5% de las escuelas en los dos municipios
# Jugar en el Azteca es mágico, pero ahora toca hacerlo en Coapa: Villacampa
# Residentes de la colonia Guadalupe Inn se oponen a cambio de uso de suelo
# Matan a chofer para robar calentadores solares
# Tras la huelga de 118 días, el SAG revela a sus favoritos: Barbie y Oppenheimer
# Unesco sugiere medidas contra desinformación y violencia extrema en redes
# Magú
# El Fisgón
# Rocha
# {'Se rebela dirigencia estatal panista; sigue en la coalición, advierte': [('ChatBot', 'Se rebela dirigencia estatal panista; sigue en la coalición, advierte'), ('ChatBot', 'Resumen: Se indigna dirigencia estatal panista ; sigue en la coalición, adviertencia estatal'), ('ChatBot', 'Completa:  Saltillo, Coah., La decisión del dirigente nacional del PAN, Marko Cortés, de romper la alianza electoral con el PRI, con miras a la próxima renovación de ayuntamientos en Coahuila, “merma el proyecto nacional” que en conjunto postula a Xóchitl Gálvez como candidata presidencial, advirtió el gobernador priísta Manolo Jiménez Salinas.')], 'Critica Enrique Alfaro “absurdo y banalidad” en destape de Álvarez Máynez': [('ChatBot', 'Critica Enrique Alfaro “absurdo y banalidad” en destape de Álvarez Máynez'), ('ChatBot', 'Resumen: El absurdo y banalidad en destape de Álvarez Máynez se destape del Áilómetro Máynz, el presidente de la Comisión de Competencia de Madrid, que ha sido destape, ha destapado de Ángel Máyndez de Álava, en la que se analizaba de de'), ('ChatBot', 'Completa:  Guadalajara, Jal., El gobernador Enrique Alfaro, emanado de Movimiento Ciudadano (MC), calificó de ocurrencia y banalidad el registro de Jorge Álvarez Máynez como precandidato presidencial. No obstante, tres de las principales figuras de ese partido a escala nacional, de origen jalisciense y que crecieron a la sombra política del mandatario, asistieron al acto celebrado este miércoles en la Ciudad de México, en un claro deslinde de las declaraciones alfaristas.')], 'Víctor M. Quintana S.: La profecía actuante de las comunidades zapatistas': [('ChatBot', 'Víctor M. Quintana S.: La profecía actuante de las comunidades zapatistas'), ('ChatBot', 'Resumen: La profecía actuante de las comunidades zapatistas de zapatistas zapatistas en el país sudamericano es una de las razones por las cuales la profecía se ha hecho viral'), ('ChatBot', 'Completa:  El EZLN no escuchó el  canto de las sirenas. Qué bueno. Desde que apareció había quienes sugerían se convirtiera en un partido político o buscara puestos de elección popular, aliándose con alguno de ellos. Esa hubiera sido la vía del desgaste, tal vez de la descomposición.')], 'Seco, al menos 70% del lago de Cuitzeo, alertan': [('ChatBot', 'Seco, al menos 70% del lago de Cuitzeo, alertan'), ('ChatBot', 'Resumen: Seco, al menos 70 % del lago de Cuitzeo, alertan los expertos sobre el lago de Potzeo'), ('ChatBot', 'Completa:  Morelia, Mich., Por primera vez en su historia reciente, en un inicio de año una parte de la zona oriente del lago de Cuitzeo, considerado el segundo más grande de México, se encuentra seca, lo que muestra el grave deterioro del embalse, cuya superficie es de más de 4 mil kilómetros cuadrados, de los cuales al menos 70 por ciento ya no tiene agua, alertaron ambientalistas de esa región que colinda con el estado de Guanajuato.')], 'El frente frío 25 deja estragos en 13 municipios de Veracruz': [('ChatBot', 'El frente frío 25 deja estragos en 13 municipios de Veracruz'), ('ChatBot', 'Resumen: El frente frío 25 deja estragos en 13 municipios de Veracruz de Veracruz'), ('ChatBot', 'Completa:  Fuertes vientos generados por el frente frío número 25 ocasionaron afectaciones en 13 municipios de Veracruz, principalmente caída de árboles y postes, así como pérdida de techos, informó la Secretaría de Protección Civil de la entidad.')], 'Washington, a favor de crear un Estado palestino, afirma Blinken ante Abbas': [('ChatBot', 'Washington, a favor de crear un Estado palestino, afirma Blinken ante Abbas'), ('ChatBot', 'Resumen: Washington, a favor de crear un Estado palestino, dice Blinken ante Abbasken'), ('ChatBot', 'Completa:  Tel Aviv. El secretario de Estado, Antony Blinken, se reunió ayer con el presidente palestino, Mahmoud Abbas, en Ramalá, donde afirmó que Estados Unidos apoya “medidas tangibles” en la creación de un Estado palestino, junto al de Israel, para que ambos países vivan “en paz y seguridad”.')], 'Tribuna ...
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\sergi\miniconda3\envs\cursoNLP\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\sergi\AppData\Local\Temp\ipykernel_17736\2118675013.py", line 48, in send_message_and_resp
#     send_message("ChatBot",get_answer(context=news[current_conversation[0]], question=message))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sergi\AppData\Local\Temp\ipykernel_17736\2118675013.py", line 2, in get_answer
#     resp = nlp(question, context)['answer']
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sergi\miniconda3\envs\cursoNLP\Lib\site-packages\transformers\pipelines\question_answering.py", line 391, in __call__
#     examples = self._args_parser(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sergi\miniconda3\envs\cursoNLP\Lib\site-packages\transformers\pipelines\question_answering.py", line 219, in __call__
#     inputs[i] = self.normalize(item)
#                 ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sergi\miniconda3\envs\cursoNLP\Lib\site-packages\transformers\pipelines\question_answering.py", line 169, in normalize
#     raise ValueError(f"`{k}` cannot be empty")
# ValueError: `question` cannot be empty
